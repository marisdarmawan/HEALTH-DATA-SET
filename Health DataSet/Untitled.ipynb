# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
HDI = pd.read_csv("Human Development Index (HDI).csv", encoding='mbcs')

# %%
HDI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 191 entries, ('HDI Rank', 'Country', '1990', nan, '1991', nan, '1992', nan, '1993', nan, '1994', nan, '1995', nan, '1996', nan, '1997', nan, '1998', nan, '1999', nan, '2000', nan, '2001', nan, '2002', nan, '2003', nan, '2004', nan, '2005', nan, '2006', nan, '2007', nan, '2008', nan, '2009', nan, '2010', nan, '2011', nan, '2012', nan, '2013', nan, '2014', nan, '2015', nan, '2016', nan, 2017.0) to (nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan)
# Data columns (total 1 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Human Development Index (HDI)  189 non-null    object
# dtypes: object(1)
# memory usage: 204.9+ KB

# %%
HDI.head()
# Out:
#                                                                                                                                                                                                                                                                                                              Human Development Index (HDI)
# HDI Rank Country      1990  NaN 1991  NaN 1992  NaN 1993  NaN 1994  NaN 1995  NaN 1996  NaN 1997  NaN 1998  NaN 1999  NaN 2000  NaN 2001  NaN 2002  NaN 2003  NaN 2004  NaN 2005  NaN 2006  NaN 2007  NaN 2008  NaN 2009  NaN 2010  NaN 2011  NaN 2012  NaN 2013  NaN 2014  NaN 2015  NaN 2016  NaN 2017.000                           NaN
# 168       Afghanistan ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  0.373 ..  0.383 ..  0.398 ..  0.408 ..  0.417 ..  0.429 ..  0.437 ..  0.453 ..  0.463 ..  0.471 ..  0.482 ..  0.487 ..  0.491 ..  0.493 ..  0.494 ..  0.498                               ..
# ...

# %%
HDI.dropna()
# Out:
#                                                                                                                                                                                                                                                                                                  Human Development Index (HDI)
# 168  Afghanistan                        ..    .. ..    .. ..    .. ..    .. ..    .. ..    .. ..    .. ..    .. ..    .. ..    .. ..    .. ..    .. 0.373 .. 0.383 .. 0.398 .. 0.408 .. 0.417 .. 0.429 .. 0.437 .. 0.453 .. 0.463 .. 0.471 .. 0.482 .. 0.487 .. 0.491 .. 0.493 .. 0.494 .. 0.498                            ..
# 68   Albania                            0.645 .. 0.626 .. 0.610 .. 0.613 .. 0.619 .. 0.632 .. 0.641 .. 0.641 .. 0.652 .. 0.662 .. 0.669 .. 0.676 .. 0.682 .. 0.689 .. 0.694 .. 0.704 .. 0.711 .. 0.720 .. 0.724 .. 0.729 .. 0.741 .. 0.752 .. 0.767 .. 0.771 .. 0.773 .. 0.776 .. 0.782 .. 0.785                            ..
# ...

# %%
HDI.head()
# Out:
#                                                                                                                                                                                                                                                                                                              Human Development Index (HDI)
# HDI Rank Country      1990  NaN 1991  NaN 1992  NaN 1993  NaN 1994  NaN 1995  NaN 1996  NaN 1997  NaN 1998  NaN 1999  NaN 2000  NaN 2001  NaN 2002  NaN 2003  NaN 2004  NaN 2005  NaN 2006  NaN 2007  NaN 2008  NaN 2009  NaN 2010  NaN 2011  NaN 2012  NaN 2013  NaN 2014  NaN 2015  NaN 2016  NaN 2017.000                           NaN
# 168       Afghanistan ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  ..    ..  0.373 ..  0.383 ..  0.398 ..  0.408 ..  0.417 ..  0.429 ..  0.437 ..  0.453 ..  0.463 ..  0.471 ..  0.482 ..  0.487 ..  0.491 ..  0.493 ..  0.494 ..  0.498                               ..
# ...

# %%
HDI['Country']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-06643bf49e9e> in <module>
# ----> 1 HDI['Country']
#
# ...
